# %% [markdown]
# # Linked Lists in Python 📚
#
# # Hyper-Detailed Notes (Beginner Friendly)
#
# This notebook is designed for someone learning Linked Lists for the first time. Every concept is explained in simple language with diagrams, examples, and code.

# %% [markdown]
# ## 1. What is a Linked List?
#
# A Linked List is a linear data structure made of **nodes**.
#
# Each node contains:
# - **Data** (the value)
# - **Next** (a reference to the next node)
#
# Unlike arrays, linked list elements are **not stored together in memory**.
#
# Visual:
#
# ```
# Head
#  ↓
# [10 | •] → [20 | •] → [30 | None]
# ```

# %% [markdown]
# ## 2. Why do we need Linked Lists?
#
# Arrays have fixed positions in memory. Inserting or deleting elements often requires shifting many values.
#
# Linked Lists solve this by connecting nodes using pointers (references).
#
# ### Advantages
# - Fast insertion/deletion at known locations.
# - Dynamic size.
#
# ### Disadvantages
# - No direct indexing.
# - Extra memory needed for references.

# %% [markdown]
# ## 3. Terminology
#
# - **Node**: One element of the linked list.
# - **Head**: First node.
# - **Tail**: Last node.
# - **Next**: Pointer/reference to next node.
# - **None**: Marks the end of the list.

# %% [markdown]
# ## 4. Creating a Node
#
# ```python
# class Node:
#     def __init__(self, data):
#         self.data = data
#         self.next = None
# ```
#
# Explanation:
#
# - `data` stores the value.
# - `next` stores the next node.
# - Initially `next = None`.

# %% [markdown]
# ## 5. Creating a Linked List
#
# ```python
# class LinkedList:
#     def __init__(self):
#         self.head = None
# ```
#
# Initially:
#
# ```
# Head
#  ↓
# None
# ```

# %% [markdown]
# ## 6. Building a Linked List Manually
#
# ```python
# n1 = Node(10)
# n2 = Node(20)
# n3 = Node(30)
#
# n1.next = n2
# n2.next = n3
#
# ll = LinkedList()
# ll.head = n1
# ```
#
# Result:
#
# ```
# Head
#  ↓
# [10|•] → [20|•] → [30|None]
# ```

# %% [markdown]
# ## 7. Traversal
#
# Traversal means visiting every node one by one.
#
# ```python
# def display(self):
#     current = self.head
#
#     while current:
#         print(current.data)
#         current = current.next
# ```
#
# The variable `current` walks through the list until it becomes `None`.

# %% [markdown]
# ## 8. Insertion
#
# ### Insert at Beginning
#
# ```python
# def insert_beginning(self, data):
#     new_node = Node(data)
#     new_node.next = self.head
#     self.head = new_node
# ```
#
# Time Complexity: **O(1)**
#
# ---
#
# ### Insert at End
#
# ```python
# def insert_end(self, data):
#     new_node = Node(data)
#
#     if self.head is None:
#         self.head = new_node
#         return
#
#     current = self.head
#
#     while current.next:
#         current = current.next
#
#     current.next = new_node
# ```
#
# Time Complexity: **O(n)**

# %% [markdown]
# ## 9. Searching
#
# ```python
# def search(self, target):
#     current = self.head
#
#     while current:
#         if current.data == target:
#             return True
#         current = current.next
#
#     return False
# ```
#
# Time Complexity: **O(n)**.

# %% [markdown]
# ## 10. Deletion
#
# Deleting a node has three common cases:
#
# 1. Empty list
# 2. Delete head
# 3. Delete any other node
#
# ```python
# def delete(self, value):
#
#     if self.head is None:
#         return
#
#     if self.head.data == value:
#         self.head = self.head.next
#         return
#
#     current = self.head
#
#     while current.next:
#         if current.next.data == value:
#             current.next = current.next.next
#             return
#         current = current.next
# ```

# %% [markdown]
# ## 11. Time Complexities
#
# | Operation | Complexity |
# |-----------|------------|
# | Access by Index | O(n) |
# | Search | O(n) |
# | Insert at Beginning | O(1) |
# | Insert at End | O(n) |
# | Delete | O(n) |

# %% [markdown]
# ## 12. Complete Implementation
#
# ```python
# class Node:
#     def __init__(self, data):
#         self.data = data
#         self.next = None
#
#
# class LinkedList:
#
#     def __init__(self):
#         self.head = None
#
#     def insert_beginning(self, data):
#         new = Node(data)
#         new.next = self.head
#         self.head = new
#
#     def insert_end(self, data):
#         new = Node(data)
#
#         if self.head is None:
#             self.head = new
#             return
#
#         current = self.head
#
#         while current.next:
#             current = current.next
#
#         current.next = new
#
#     def display(self):
#         current = self.head
#
#         while current:
#             print(current.data, end=" -> ")
#             current = current.next
#         print("None")
#
#     def search(self, value):
#         current = self.head
#
#         while current:
#             if current.data == value:
#                 return True
#             current = current.next
#         return False
#
#     def delete(self, value):
#
#         if self.head is None:
#             return
#
#         if self.head.data == value:
#             self.head = self.head.next
#             return
#
#         current = self.head
#
#         while current.next:
#             if current.next.data == value:
#                 current.next = current.next.next
#                 return
#             current = current.next
# ```

# %% [markdown]
# ## 13. Interview Tips
#
# Remember these points:
#
# - Every node stores **data + next**.
# - `head` points to the first node.
# - Traversal always uses a temporary pointer (`current`).
# - Never lose the `head` pointer.
# - Always check for an empty list before performing operations.

# %% [markdown]
# ## 14. Practice Questions
#
# 1. Traverse a linked list.
# 2. Insert at beginning.
# 3. Insert at end.
# 4. Delete first node.
# 5. Delete last node.
# 6. Reverse a linked list.
# 7. Find middle node.
# 8. Detect a cycle.
# 9. Merge two sorted linked lists.
# 10. Remove duplicates.

# %%
# Example Usage

ll = LinkedList()

ll.insert_end(10)
ll.insert_end(20)
ll.insert_end(30)

ll.display()

print("Search 20:", ll.search(20))

ll.delete(20)

ll.display()
